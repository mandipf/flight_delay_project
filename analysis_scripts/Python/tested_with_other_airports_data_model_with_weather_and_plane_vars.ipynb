# %% [markdown]
# # Model with weather and plane variables (delay_flag) tested with other airport data

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import roc_auc_score, roc_curve

import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# %% [markdown]
# # Import flight data, then filter delay_flag

# %%
flight_data = pd.read_csv("../../data/clean_data/flight_delay_clean.csv")
flight_data.shape
# Out:
# (303748, 24)

# %%
# filter for only delay and no delay data
flight_delay_data = flight_data[flight_data['delay_flag'] != "Cancelled"].copy()
flight_delay_data.shape
# Out:
# (295938, 24)

# %%
# convert outcome flag to numeric data from category
flight_delay_data['delayed_flag'] = (np.where(flight_delay_data['delay_flag'] == "Yes", 1, 0))
list(flight_delay_data)
# Out:
# ['sch_departure',
#  'month',
#  'wday',
#  'hour',
#  'cycle',
#  'flights_per_day',
#  'flights_per_hour',
#  'origin',
#  'dep_delay',
#  'delay_flag',
#  'dest',
#  'distance',
#  'nose_dir',
#  'carrier',
#  'type',
#  'seats',
#  'wind_dir',
#  'wind_speed',
#  'visib',
#  'prcp',
#  'snow',
#  'snwd',
#  'tavg',
#  'pres',
#  'delayed_flag']

# %% [markdown]
# # Select required variables

# %%
delay_df = flight_delay_data[['delayed_flag', 'wind_dir', 'wind_speed', 'visib',
                              'prcp', 'snow', 'snwd', 'tavg', 'pres', 'origin',
                              'dest', 'distance', 'nose_dir', 'carrier', 'type',
                              'seats']].dropna().copy()
delay_df.shape
# Out:
# (258868, 16)

# %% [markdown]
# # Build and test model with EWR
#
# ## Filter airline data

# %%
# filter for required airlines
ewr_delay_data = delay_df[delay_df['origin'] == "EWR"].copy()
ewr_delay_data = ewr_delay_data.drop('origin', axis=1)
ewr_delay_data.reset_index(inplace=True, drop=True)
ewr_delay_data.shape
# Out:
# (106154, 15)

# %%
ewr_delay_data.describe()
# Out:
#         delayed_flag       wind_dir     wind_speed          visib  \
# count  106154.000000  106154.000000  106154.000000  106154.000000
# mean        0.249694     181.633476       8.469124       9.376744
# std         0.432838     113.723394       4.455318       1.817035
# min         0.000000       0.000000       0.000000       0.130000
# 25%         0.000000      70.000000       5.753900      10.000000
# 50%         0.000000     210.000000       8.055460      10.000000
# 75%         0.000000     270.000000      11.507800      10.000000
# max         1.000000     360.000000      26.467940      10.000000
#
#                 prcp           snow           snwd           tavg  \
# count  106154.000000  106154.000000  106154.000000  106154.000000
# mean        0.119123       0.046877       0.166763      57.039848
# std         0.371772       0.405915       0.760415      16.803644
# min         0.000000       0.000000       0.000000      16.000000
# 25%         0.000000       0.000000       0.000000      43.000000
# 50%         0.000000       0.000000       0.000000      58.000000
# 75%         0.040000       0.000000       0.000000      72.000000
# max         3.860000       7.800000       5.900000      87.000000
#
#                 pres       distance       nose_dir          seats
# count  106154.000000  106154.000000  106154.000000  106154.000000
# mean     1017.157612    1148.424440     231.954600     152.126910
# std         6.855320     779.527254      63.288802      76.943562
# min       995.800000      93.000000       7.496324       1.000000
# 25%      1013.200000     631.000000     207.829268     100.000000
# 50%      1016.300000     937.000000     244.843285     149.000000
# 75%      1021.300000    1605.000000     278.009949     191.000000
# max      1039.100000    4962.000000     329.743683     552.000000

# %%
# create dummies if required
ewr_delay_data = pd.get_dummies(ewr_delay_data, drop_first = True)
ewr_delay_data.shape
# Out:
# (106154, 114)

# %% [markdown]
# ## Separate response and scale features

# %%
ewr_predictors = ewr_delay_data.drop(columns = 'delayed_flag')
ewr_response = ewr_delay_data['delayed_flag']

# %%
# scale features
ss = StandardScaler()
ewr_predictors_scaled = ss.fit_transform(ewr_predictors)
ewr_predictors = pd.DataFrame(ewr_predictors_scaled, columns = ewr_predictors.columns)

# %%
# ewr_predictors.mean()

# %%
# ewr_predictors.std()

# %% [markdown]
# ## Split the data

# %%
# create test/train split (80%:20%)
ewr_pred_train, ewr_pred_test, ewr_resp_train, ewr_resp_test = (
    train_test_split(
        ewr_predictors, 
        ewr_response, 
        test_size = 0.2, 
        random_state = 7
    )
)

ewr_pred_train.shape, ewr_pred_test.shape
# Out:
# ((84923, 113), (21231, 113))

# %%
# create balanced train set
bal_ewr_pred_train, bal_ewr_resp_train = ewr_pred_train, ewr_resp_train.copy()
print(Counter(bal_ewr_resp_train))

under = RandomUnderSampler(sampling_strategy=1)
bal_ewr_pred_train, bal_ewr_resp_train = under.fit_resample(bal_ewr_pred_train, bal_ewr_resp_train)
print(Counter(bal_ewr_resp_train))
# Out:
# Counter({0: 63752, 1: 21171})
# Counter({0: 21171, 1: 21171})

# %% [markdown]
# ## Run the model

# %%
# run the model with parameters from grid
model = RandomForestClassifier(max_depth=6,
                               max_features="log2",
                               max_leaf_nodes=9,
                               n_estimators=150)

# train the model on the training data
model.fit(bal_ewr_pred_train, bal_ewr_resp_train)
# Out:
# RandomForestClassifier(max_depth=6, max_features='log2', max_leaf_nodes=9,
#                        n_estimators=150)

# %%
accuracy_scores = cross_val_score(
    model, bal_ewr_pred_train, bal_ewr_resp_train, scoring='accuracy', cv=10
)

np.mean(accuracy_scores)
# Out:
# 0.5891783387308787

# %%
roc_scores = cross_val_score(
    model, bal_ewr_pred_train, bal_ewr_resp_train, scoring='roc_auc', cv=10
)

np.mean(roc_scores)
# Out:
# 0.6268097743607682

# %%
# create a list with names of predictors, and an array with target categories for plotting
ewr_pred_names = list(ewr_pred_test)
ewr_resp_names = ['OnTime', 'Delayed']

# %%
# set the figure size
fig = plt.figure(figsize=(80, 40))

# plot the decision tree
plot_tree(model.estimators_[0], # Pull out one tree from the forest
          max_depth = 5,
          feature_names = ewr_pred_names,
          class_names = ewr_resp_names, 
          filled=True,
          fontsize=10,
          rounded=True)

plt.show()

# %%
importances = list(model.feature_importances_)

feature_importances = [(feature, round(importance, 2)) for feature,
                       importance in zip(ewr_pred_names, importances)]

feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

[print('Variable: {:40} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: prcp                                     Importance: 0.15
# Variable: visib                                    Importance: 0.13
# Variable: pres                                     Importance: 0.13
# Variable: snwd                                     Importance: 0.08
# Variable: tavg                                     Importance: 0.07
# Variable: carrier_JetBlue Airways                  Importance: 0.06
# Variable: seats                                    Importance: 0.05
# Variable: distance                                 Importance: 0.04
# Variable: carrier_United Air Lines                 Importance: 0.04
# Variable: wind_dir                                 Importance: 0.03
# Variable: wind_speed                               Importance: 0.02
# Variable: snow                                     Importance: 0.02
# Variable: nose_dir                                 Importance: 0.02
# Variable: dest_FWA                                 Importance: 0.02
# Variable: dest_CAK                                 Importance: 0.01
# Variable: dest_CMH                                 Importance: 0.01
# Variable: dest_MYR                                 Importance: 0.01
# Variable: dest_SBN                                 Importance: 0.01
# Variable: dest_SEA                                 Importance: 0.01
# Variable: dest_SNA                                 Importance: 0.01
# Variable: carrier_American Airlines                Importance: 0.01
# Variable: carrier_Delta Air Lines                  Importance: 0.01
# Variable: dest_ANC                                 Importance: 0.0
# Variable: dest_ATL                                 Importance: 0.0
# Variable: dest_AUS                                 Importance: 0.0
# Variable: dest_AVL                                 Importance: 0.0
# Variable: dest_AVP                                 Importance: 0.0
# Variable: dest_BDL                                 Importance: 0.0
# Variable: dest_BGR                                 Importance: 0.0
# Variable: dest_BNA                                 Importance: 0.0
# Variable: dest_BOS                                 Importance: 0.0
# Variable: dest_BQN                                 Importance: 0.0
# Variable: dest_BTV                                 Importance: 0.0
# Variable: dest_BUF                                 Importance: 0.0
# Variable: dest_BWI                                 Importance: 0.0
# Variable: dest_BZN                                 Importance: 0.0
# Variable: dest_CHA                                 Importance: 0.0
# Variable: dest_CHS                                 Importance: 0.0
# Variable: dest_CLE                                 Importance: 0.0
# Variable: dest_CLT                                 Importance: 0.0
# Variable: dest_CVG                                 Importance: 0.0
# Variable: dest_DAY                                 Importance: 0.0
# Variable: dest_DCA                                 Importance: 0.0
# Variable: dest_DEN                                 Importance: 0.0
# Variable: dest_DFW                                 Importance: 0.0
# Variable: dest_DSM                                 Importance: 0.0
# Variable: dest_DTW                                 Importance: 0.0
# Variable: dest_EGE                                 Importance: 0.0
# Variable: dest_FLL                                 Importance: 0.0
# Variable: dest_FNT                                 Importance: 0.0
# Variable: dest_GRR                                 Importance: 0.0
# Variable: dest_GSO                                 Importance: 0.0
# Variable: dest_GSP                                 Importance: 0.0
# Variable: dest_HDN                                 Importance: 0.0
# Variable: dest_HNL                                 Importance: 0.0
# Variable: dest_IAD                                 Importance: 0.0
# Variable: dest_IAH                                 Importance: 0.0
# Variable: dest_IND                                 Importance: 0.0
# Variable: dest_JAC                                 Importance: 0.0
# Variable: dest_JAX                                 Importance: 0.0
# Variable: dest_LAS                                 Importance: 0.0
# Variable: dest_LAX                                 Importance: 0.0
# Variable: dest_LEX                                 Importance: 0.0
# Variable: dest_MCI                                 Importance: 0.0
# Variable: dest_MCO                                 Importance: 0.0
# Variable: dest_MDW                                 Importance: 0.0
# Variable: dest_MEM                                 Importance: 0.0
# Variable: dest_MHT                                 Importance: 0.0
# Variable: dest_MIA                                 Importance: 0.0
# Variable: dest_MKE                                 Importance: 0.0
# Variable: dest_MSN                                 Importance: 0.0
# Variable: dest_MSP                                 Importance: 0.0
# Variable: dest_MSY                                 Importance: 0.0
# Variable: dest_MTJ                                 Importance: 0.0
# Variable: dest_OAK                                 Importance: 0.0
# Variable: dest_OMA                                 Importance: 0.0
# Variable: dest_ORD                                 Importance: 0.0
# Variable: dest_ORF                                 Importance: 0.0
# Variable: dest_PBI                                 Importance: 0.0
# Variable: dest_PDX                                 Importance: 0.0
# Variable: dest_PHX                                 Importance: 0.0
# Variable: dest_PIT                                 Importance: 0.0
# Variable: dest_PVD                                 Importance: 0.0
# Variable: dest_PWM                                 Importance: 0.0
# Variable: dest_RDU                                 Importance: 0.0
# Variable: dest_RIC                                 Importance: 0.0
# Variable: dest_ROC                                 Importance: 0.0
# Variable: dest_RSW                                 Importance: 0.0
# Variable: dest_SAN                                 Importance: 0.0
# Variable: dest_SAT                                 Importance: 0.0
# Variable: dest_SAV                                 Importance: 0.0
# Variable: dest_SDF                                 Importance: 0.0
# Variable: dest_SFO                                 Importance: 0.0
# Variable: dest_SJC                                 Importance: 0.0
# Variable: dest_SJU                                 Importance: 0.0
# Variable: dest_SLC                                 Importance: 0.0
# Variable: dest_SMF                                 Importance: 0.0
# Variable: dest_SRQ                                 Importance: 0.0
# Variable: dest_STL                                 Importance: 0.0
# Variable: dest_STT                                 Importance: 0.0
# Variable: dest_SYR                                 Importance: 0.0
# Variable: dest_TPA                                 Importance: 0.0
# Variable: dest_TVC                                 Importance: 0.0
# Variable: dest_TYS                                 Importance: 0.0
# Variable: dest_XNA                                 Importance: 0.0
# Variable: carrier_ExpressJet Airlines              Importance: 0.0
# Variable: carrier_SkyWest Airlines                 Importance: 0.0
# Variable: carrier_Southwest Airlines               Importance: 0.0
# Variable: carrier_Spirit Air Lines                 Importance: 0.0
# Variable: carrier_Virgin America                   Importance: 0.0
# Variable: type_Fixed wing single engine            Importance: 0.0
# Variable: type_Rotorcraft                          Importance: 0.0
# Variable: type_Weight-shift-control                Importance: 0.0

# %% [markdown]
# ## Confusion matrix and classification report

# %%
# create balanced test set
bal_ewr_pred_test, bal_ewr_resp_test = ewr_pred_test, ewr_resp_test.copy()
print(Counter(bal_ewr_resp_test))

under = RandomUnderSampler(sampling_strategy=1)
bal_ewr_pred_test, bal_ewr_resp_test = under.fit_resample(bal_ewr_pred_test, bal_ewr_resp_test)
print(Counter(bal_ewr_resp_test))
# Out:
# Counter({0: 15896, 1: 5335})
# Counter({0: 5335, 1: 5335})

# %%
y_pred = model.predict(bal_ewr_pred_test)
cm = confusion_matrix(bal_ewr_resp_test, y_pred)
cm
# Out:
# array([[3412, 1923],
#        [2395, 2940]], dtype=int64)

# %%
# plot confusion matrix
cm = confusion_matrix(bal_ewr_resp_test, y_pred, labels=model.classes_)
color = 'white'
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["On Time", "Delayed"])
disp.plot()
plt.show()

# %%
# get classification report
print(classification_report(bal_ewr_resp_test, y_pred, target_names=['On Time', 'Delayed']))
# Out:
#               precision    recall  f1-score   support
#
#      On Time       0.59      0.64      0.61      5335
#      Delayed       0.60      0.55      0.58      5335
#
#     accuracy                           0.60     10670
#    macro avg       0.60      0.60      0.59     10670
# weighted avg       0.60      0.60      0.59     10670

# %%
# get ROC curve

y_score = model.predict_proba(bal_ewr_pred_test)[:, 1]

fpr, tpr, threshold = roc_curve(bal_ewr_resp_test, y_score)
auc = roc_auc_score(bal_ewr_resp_test, y_score)
random_probs = [0 for i in range(len(bal_ewr_resp_test))]
p_fpr, p_tpr, threshold = roc_curve(bal_ewr_resp_test, random_probs, pos_label=1)

#create ROC curve
plt.rcParams.update({'font.size': 15})
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.plot(p_fpr, p_tpr, linestyle='--', color='black')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # Test model with JFK
#
# ## Filter airline data

# %%
# filter for required airlines
jfk_delay_data = delay_df[delay_df['origin'] == "JFK"].copy()
jfk_delay_data = jfk_delay_data.drop('origin', axis=1)
jfk_delay_data.reset_index(inplace=True, drop=True)
jfk_delay_data.shape
# Out:
# (78642, 15)

# %%
# create dummies if required
jfk_delay_data = pd.get_dummies(jfk_delay_data, drop_first = True)
jfk_delay_data.shape
# Out:
# (78642, 79)

# %% [markdown]
# ## Separate response and scale features

# %%
jfk_predictors = jfk_delay_data.drop(columns = 'delayed_flag')
jfk_response = jfk_delay_data['delayed_flag']

# %%
# scale features
ss = StandardScaler()
jfk_predictors_scaled = ss.fit_transform(jfk_predictors)
jfk_predictors = pd.DataFrame(jfk_predictors_scaled, columns = jfk_predictors.columns)

# %%
# jfk_predictors.mean()

# %%
# jfk_predictors.std()

# %% [markdown]
# ## Test EWR model with new data
#
# This model cannot be run with JFK data as the carriers and destinations are different between these airports.
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - carrier_Hawaiian Airlines
# - dest_ACK
# - dest_BUR
# - dest_DAB
# - dest_HOU
# - ...
# Feature names seen at fit time, yet now missing:
# - carrier_ExpressJet Airlines
# - carrier_SkyWest Airlines
# - carrier_Southwest Airlines
# - carrier_Spirit Air Lines
# - carrier_United Air Lines
# - ...

# %% [markdown]
# # Test model with LGA
#
# ## Filter airline data

# %%
# filter for required airlines
lga_delay_data = delay_df[delay_df['origin'] == "LGA"].copy()
lga_delay_data = lga_delay_data.drop('origin', axis=1)
lga_delay_data.reset_index(inplace=True, drop=True)
lga_delay_data.shape
# Out:
# (74072, 15)

# %%
# create dummies if required
lga_delay_data = pd.get_dummies(lga_delay_data, drop_first = True)
lga_delay_data.shape
# Out:
# (74072, 88)

# %% [markdown]
# ## Separate response and scale features

# %%
lga_predictors = lga_delay_data.drop(columns = 'delayed_flag')
lga_response = lga_delay_data['delayed_flag']

# %%
# scale features
ss = StandardScaler()
lga_predictors_scaled = ss.fit_transform(lga_predictors)
lga_predictors = pd.DataFrame(lga_predictors_scaled, columns = lga_predictors.columns)

# %%
# lga_predictors.mean()

# %%
# lga_predictors.std()

# %% [markdown]
# ## Test EWR model with new data
#
# This model cannot be run with LGA data as the carriers and destinations are different between these airports.
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - carrier_Frontier Airlines
# - dest_BHM
# - dest_CAE
# - dest_CHO
# - dest_DAL
# - ...
# Feature names seen at fit time, yet now missing:
# - carrier_American Airlines
# - dest_ANC
# - dest_ATL
# - dest_AUS
# - dest_AVP
# - ...
